# %% [markdown]
# # PART-2 OF PANDAS LIBRARY

# %%
import pandas as pd

# %%
 df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[["Name"]]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
a=df["Name"][0:11]

# %%
a
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
l=["umar","dd","ff","gg","hh","ww","rr","ff","","uu","hh"]

# %%
pd.Series(a,index=l)
# Out:
# umar    NaN
# dd      NaN
# ff      NaN
# gg      NaN
# hh      NaN
# ww      NaN
# rr      NaN
# ff      NaN
#         NaN
# uu      NaN
# hh      NaN
# Name: Name, dtype: object

# %%
pd.Series(list(a), index=l)
# Out:
# umar                              Braund, Mr. Owen Harris
# dd      Cumings, Mrs. John Bradley (Florence Briggs Th...
# ff                                 Heikkinen, Miss. Laina
# gg           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# hh                               Allen, Mr. William Henry
# ww                                       Moran, Mr. James
# rr                                McCarthy, Mr. Timothy J
# ff                         Palsson, Master. Gosta Leonard
#         Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# uu                    Nasser, Mrs. Nicholas (Adele Achem)
# hh                        Sandstrom, Miss. Marguerite Rut
# dtype: object

# %%
m1=pd.Series([100,200,300,400,500], index=[2,3,4,5,7])

# %% [markdown]
# #

# %%
m1
# Out:
# 2    100
# 3    200
# 4    300
# 5    400
# 7    500
# dtype: int64

# %%
m2=pd.Series([500,600,700,800,900], index=[3,4,5,6,7])
#for making data frame we can use pd.Series

# %%
m2
# Out:
# 3    500
# 4    600
# 5    700
# 6    800
# 7    900
# dtype: int64

# %% [markdown]
# # CONCATINATION

# %%
m3=pd.concat([m1,m2])
m3
# Out:
# 2    100
# 3    200
# 4    300
# 5    400
# 7    500
# 3    500
# 4    600
# 5    700
# 6    800
# 7    900
# dtype: int64

# %%
m3[7]
# Out:
# 7    500
# 7    900
# dtype: int64

# %%
m1*m2
# Out:
# 2         NaN
# 3    100000.0
# 4    180000.0
# 5    280000.0
# 6         NaN
# 7    450000.0
# dtype: float64

# %%
m1+m2
# Out:
# 2       NaN
# 3     700.0
# 4     900.0
# 5    1100.0
# 6       NaN
# 7    1400.0
# dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # DELETTION OF COLUMN

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('Sex',axis=1)
#axis 1 means column
#axis 0 means row
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('Sex',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %% [markdown]
# # DELETING ROWS

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
df.drop(4,axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 5                                     Moran, Mr. James   NaN      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
#use inplace=True for permanent deletion
df.drop(4,axis=0,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 5                                     Moran, Mr. James   NaN      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %% [markdown]
# # MAKING COLUMN AN INDEX

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 5                                     Moran, Mr. James   NaN      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
df.set_index("Name")
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 5                                     Moran, Mr. James   NaN      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
#use inplace = True for permannet change
df.set_index("Name",inplace=True)

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Moran, Mr. James                                              6         0
#
#                                                     Pclass   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                                  3  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  38.0      1
# Heikkinen, Miss. Laina                                   3  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  35.0      1
# Moran, Mr. James                                         3   NaN      0
#
# ...

# %% [markdown]
# # HOW TO RESET index

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %% [markdown]
# # MAKING DATA FRAME FROM THE DICTIONARY

# %%
d={"k1":(1,2,3),"k2":(4,5,6),"k3":(7,8,9)}

# %%
print(d)
# Out:
# {'k1': (1, 2, 3), 'k2': (4, 5, 6), 'k3': (7, 8, 9)}

# %%
pd.DataFrame(d)
#it help us to convert dictionary into a data frame
# Out:
#    k1  k2  k3
# 0   1   4   7
# 1   2   5   8
# 2   3   6   9

# %%
df1=pd.read_csv("https://gist.githubusercontent.com/JordanLyons/139e6cf1dafa0b8cb5ae32f6facef8a4/raw/6bf4a1baf7a9245cf2f0b16feefa86672bf39b19/free-taxonomy.csv")

# %%
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %% [markdown]
# # DELETING ALL ROWS WHICH CONATIAN NAN DATA

# %%
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df1.dropna()
# Out:
# Empty DataFrame
# Columns: [name, id, parent_name, parent_id, vocabulary, x-description, x-notes, services]
# Index: []

# %%
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %% [markdown]
# # DELETING ALL column WHICH CONATIAN NAN DATA

# %%
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df1.dropna(axis=1)
# Out:
#                         name     id                         vocabulary
# 0                  Emergency   1101    Open Eligibility Human Services
# 1                       Food   1102    Open Eligibility Human Services
# 2                    Housing   1103    Open Eligibility Human Services
# 3                      Goods   1104    Open Eligibility Human Services
# 4                    Transit   1105    Open Eligibility Human Services
# ..                       ...    ...                                ...
# 322                In Danger  20089  Open Eligibility Human Situations
# 323          Chronic Illness  20090  Open Eligibility Human Situations
# 324                  Spouses  20091  Open Eligibility Human Situations
# 325               Dependents  20092  Open Eligibility Human Situations
# 326  Intellectual Disability  20093  Open Eligibility Human Situations
#
# [327 rows x 3 columns]

# %%
df1
#we can also use inplace=True  for permanent deleltion
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %% [markdown]
# # REPLACING NAN WITH ALAM

# %%
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df1.fillna("alam")
#for permanent changes we can use inplace=True
# Out:
#                         name     id parent_name parent_id  \
# 0                  Emergency   1101           0       0.0
# 1                       Food   1102           0       0.0
# 2                    Housing   1103           0       0.0
# 3                      Goods   1104           0       0.0
# 4                    Transit   1105           0       0.0
# ..                       ...    ...         ...       ...
# 322                In Danger  20089     Urgency   20087.0
# 323          Chronic Illness  20090      Health    1106.0
# 324                  Spouses  20091        Role   20072.0
# 325               Dependents  20092        Role   20072.0
# 326  Intellectual Disability  20093  Disability   20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...
