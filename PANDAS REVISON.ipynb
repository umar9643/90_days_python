# %%
import pandas as pd

# %%
da=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
da.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
da.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
da.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
da.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
da[["Name"]]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
da[["Name","Cabin"]]
# Out:
#                                                   Name Cabin
# 0                              Braund, Mr. Owen Harris   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   C85
# 2                               Heikkinen, Miss. Laina   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# 4                             Allen, Mr. William Henry   NaN
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas   NaN
# 887                       Graham, Miss. Margaret Edith   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  C148
# 890                                Dooley, Mr. Patrick   NaN
#
# [891 rows x 2 columns]

# %%
da.dtypes==("int64")
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name           False
# Sex            False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
da.dtypes=="Float64"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
da.dtypes==("float64")
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
da[da.dtypes[da.dtypes==("float64")].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
da[da.dtypes[da.dtypes==("float64")].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
da[da.dtypes[da.dtypes==("float64")].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
da[da.dtypes[da.dtypes==("float64")].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
da.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
da.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# ...

# %%
da.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # SLICING IN PANDA

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
da[["Name"]][1:10]
# Out:
#                                                 Name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James
# 6                            McCarthy, Mr. Timothy J
# 7                     Palsson, Master. Gosta Leonard
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                Nasser, Mrs. Nicholas (Adele Achem)

# %%
da[["Name","Age"]][1:20:2]
# Out:
#                                                  Name   Age
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                    Moran, Mr. James   NaN
# 7                      Palsson, Master. Gosta Leonard   2.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 11                           Bonnell, Miss. Elizabeth  58.0
# 13                        Andersson, Mr. Anders Johan  39.0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   55.0
# 17                       Williams, Mr. Charles Eugene   NaN
# 19                            Masselmani, Mrs. Fatima   NaN

# %%
da[["Name","Age"]][::-1]
# Out:
#                                                   Name   Age
# 890                                Dooley, Mr. Patrick  32.0
# 889                              Behr, Mr. Karl Howell  26.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 887                       Graham, Miss. Margaret Edith  19.0
# 886                              Montvila, Rev. Juozas  27.0
# ..                                                 ...   ...
# 4                             Allen, Mr. William Henry  35.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 2                               Heikkinen, Miss. Laina  26.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 0                              Braund, Mr. Owen Harris  22.0
#
# [891 rows x 2 columns]

# %%
da[["Name","Age"]][::2]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 2                               Heikkinen, Miss. Laina  26.0
# 4                             Allen, Mr. William Henry  35.0
# 6                              McCarthy, Mr. Timothy J  54.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# ..                                                 ...   ...
# 882                       Dahlberg, Miss. Gerda Ulrika  22.0
# 884                             Sutehall, Mr. Henry Jr  25.0
# 886                              Montvila, Rev. Juozas  27.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                                Dooley, Mr. Patrick  32.0
#
# [446 rows x 2 columns]

# %% [markdown]
# # ADDING A NEW COLUMN

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
da["new"]=7

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # deletion of a column

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
da.drop("Name",axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
da
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
da.drop("Name",axis=1,inplace=True)
#for permanently deleting the column

# %%
da
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# # DELETION OF ROWS

# %%
da
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
da.drop(2,axis=0)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 0              1         0       3    male  22.0      1      0   A/5 21171
# 1              2         1       1  female  38.0      1      0    PC 17599
# 3              4         1       1  female  35.0      1      0      113803
# 4              5         0       3    male  35.0      0      0      373450
# 5              6         0       3    male   NaN      0      0      330877
# ..           ...       ...     ...     ...   ...    ...    ...         ...
# 886          887         0       2    male  27.0      0      0      211536
# 887          888         1       1  female  19.0      0      0      112053
# 888          889         0       3  female   NaN      1      2  W./C. 6607
# 889          890         1       1    male  26.0      0      0      111369
# 890          891         0       3    male  32.0      0      0      370376
#
#         Fare Cabin Embarked
# 0     7.2500   NaN        S
# ...

# %%
da.drop(2,axis=0,inplace=True)

# %%
da
# Out:
#          PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# Fare
# 7.2500             1         0       3    male  22.0      1      0
# 71.2833            2         1       1  female  38.0      1      0
# 53.1000            4         1       1  female  35.0      1      0
# 8.0500             5         0       3    male  35.0      0      0
# 8.4583             6         0       3    male   NaN      0      0
# ...              ...       ...     ...     ...   ...    ...    ...
# 13.0000          887         0       2    male  27.0      0      0
# 30.0000          888         1       1  female  19.0      0      0
# 23.4500          889         0       3  female   NaN      1      2
# 30.0000          890         1       1    male  26.0      0      0
# 7.7500           891         0       3    male  32.0      0      0
#
#              Ticket Cabin Embarked
# Fare
# 7.2500    A/5 21171   NaN        S
# 71.2833    PC 17599   C85        C
# 53.1000      113803  C123        S
# ...

# %% [markdown]
# # MAKING COLUMN AN INDEX

# %%
da
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 0              1         0       3    male  22.0      1      0   A/5 21171
# 1              2         1       1  female  38.0      1      0    PC 17599
# 3              4         1       1  female  35.0      1      0      113803
# 4              5         0       3    male  35.0      0      0      373450
# 5              6         0       3    male   NaN      0      0      330877
# ..           ...       ...     ...     ...   ...    ...    ...         ...
# 886          887         0       2    male  27.0      0      0      211536
# 887          888         1       1  female  19.0      0      0      112053
# 888          889         0       3  female   NaN      1      2  W./C. 6607
# 889          890         1       1    male  26.0      0      0      111369
# 890          891         0       3    male  32.0      0      0      370376
#
#         Fare Cabin Embarked
# 0     7.2500   NaN        S
# ...

# %%
da.set_index("Sex")
# Out:
#         PassengerId  Survived  Pclass   Age  SibSp  Parch      Ticket  \
# Sex
# male              1         0       3  22.0      1      0   A/5 21171
# female            2         1       1  38.0      1      0    PC 17599
# female            4         1       1  35.0      1      0      113803
# male              5         0       3  35.0      0      0      373450
# male              6         0       3   NaN      0      0      330877
# ...             ...       ...     ...   ...    ...    ...         ...
# male            887         0       2  27.0      0      0      211536
# female          888         1       1  19.0      0      0      112053
# female          889         0       3   NaN      1      2  W./C. 6607
# male            890         1       1  26.0      0      0      111369
# male            891         0       3  32.0      0      0      370376
#
#            Fare Cabin Embarked
# Sex
# male     7.2500   NaN        S
# female  71.2833   C85        C
# ...

# %%
da.set_index("Fare",inplace=True)

# %%
da
# Out:
#          PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# Fare
# 7.2500             1         0       3    male  22.0      1      0
# 71.2833            2         1       1  female  38.0      1      0
# 53.1000            4         1       1  female  35.0      1      0
# 8.0500             5         0       3    male  35.0      0      0
# 8.4583             6         0       3    male   NaN      0      0
# ...              ...       ...     ...     ...   ...    ...    ...
# 13.0000          887         0       2    male  27.0      0      0
# 30.0000          888         1       1  female  19.0      0      0
# 23.4500          889         0       3  female   NaN      1      2
# 30.0000          890         1       1    male  26.0      0      0
# 7.7500           891         0       3    male  32.0      0      0
#
#              Ticket Cabin Embarked
# Fare
# 7.2500    A/5 21171   NaN        S
# 71.2833    PC 17599   C85        C
# 53.1000      113803  C123        S
# ...

# %%
da.reset_index()
# Out:
#         Fare  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0     7.2500            1         0       3    male  22.0      1      0
# 1    71.2833            2         1       1  female  38.0      1      0
# 2    53.1000            4         1       1  female  35.0      1      0
# 3     8.0500            5         0       3    male  35.0      0      0
# 4     8.4583            6         0       3    male   NaN      0      0
# ..       ...          ...       ...     ...     ...   ...    ...    ...
# 885  13.0000          887         0       2    male  27.0      0      0
# 886  30.0000          888         1       1  female  19.0      0      0
# 887  23.4500          889         0       3  female   NaN      1      2
# 888  30.0000          890         1       1    male  26.0      0      0
# 889   7.7500          891         0       3    male  32.0      0      0
#
#          Ticket Cabin Embarked
# 0     A/5 21171   NaN        S
# 1      PC 17599   C85        C
# ...

# %%
da
# Out:
#          PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# Fare
# 7.2500             1         0       3    male  22.0      1      0
# 71.2833            2         1       1  female  38.0      1      0
# 53.1000            4         1       1  female  35.0      1      0
# 8.0500             5         0       3    male  35.0      0      0
# 8.4583             6         0       3    male   NaN      0      0
# ...              ...       ...     ...     ...   ...    ...    ...
# 13.0000          887         0       2    male  27.0      0      0
# 30.0000          888         1       1  female  19.0      0      0
# 23.4500          889         0       3  female   NaN      1      2
# 30.0000          890         1       1    male  26.0      0      0
# 7.7500           891         0       3    male  32.0      0      0
#
#              Ticket Cabin Embarked
# Fare
# 7.2500    A/5 21171   NaN        S
# 71.2833    PC 17599   C85        C
# 53.1000      113803  C123        S
# ...

# %%
da.reset_index(inplace=True)

# %%
da
# Out:
#         Fare  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0     7.2500            1         0       3    male  22.0      1      0
# 1    71.2833            2         1       1  female  38.0      1      0
# 2    53.1000            4         1       1  female  35.0      1      0
# 3     8.0500            5         0       3    male  35.0      0      0
# 4     8.4583            6         0       3    male   NaN      0      0
# ..       ...          ...       ...     ...     ...   ...    ...    ...
# 885  13.0000          887         0       2    male  27.0      0      0
# 886  30.0000          888         1       1  female  19.0      0      0
# 887  23.4500          889         0       3  female   NaN      1      2
# 888  30.0000          890         1       1    male  26.0      0      0
# 889   7.7500          891         0       3    male  32.0      0      0
#
#          Ticket Cabin Embarked
# 0     A/5 21171   NaN        S
# 1      PC 17599   C85        C
# ...

# %%
da
# Out:
#         Fare  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0     7.2500            1         0       3    male  22.0      1      0
# 1    71.2833            2         1       1  female  38.0      1      0
# 2    53.1000            4         1       1  female  35.0      1      0
# 3     8.0500            5         0       3    male  35.0      0      0
# 4     8.4583            6         0       3    male   NaN      0      0
# ..       ...          ...       ...     ...     ...   ...    ...    ...
# 885  13.0000          887         0       2    male  27.0      0      0
# 886  30.0000          888         1       1  female  19.0      0      0
# 887  23.4500          889         0       3  female   NaN      1      2
# 888  30.0000          890         1       1    male  26.0      0      0
# 889   7.7500          891         0       3    male  32.0      0      0
#
#          Ticket Cabin Embarked
# 0     A/5 21171   NaN        S
# 1      PC 17599   C85        C
# ...
